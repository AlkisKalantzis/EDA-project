# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
from datetime import datetime
import seaborn as sns

# %% [markdown]
# # 00s

# %%
spot00 = pd.read_csv(r"dataset-of-00s.csv")
spot00.head(3)
# Out:
#                 track             artist  \
# 0           Lucky Man  Montgomery Gentry
# 1      On The Hotline       Pretty Ricky
# 2  Clouds Of Dementia         Candlemass
#
#                                     uri  danceability  energy  key  loudness  \
# 0  spotify:track:4GiXBCUF7H6YfNQsnBRIzl         0.578   0.471    4    -7.270
# 1  spotify:track:1zyqZONW985Cs4osz9wlsu         0.704   0.854   10    -5.477
# 2  spotify:track:6cHZf7RbxXCKwEkgAZT4mY         0.162   0.836    9    -3.009
#
#    mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1       0.0289      0.368000           0.00000     0.159    0.532
# 1     0       0.1830      0.018500           0.00000     0.148    0.688
# 2     1       0.0473      0.000111           0.00457     0.174    0.300
#
#      tempo  duration_ms  time_signature  chorus_hit  sections  target
# 0  133.061       196707               4    30.88059        13       1
# ...

# %%
cols=['danceability' , 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'valence', 'duration_ms']

# %%
for attribute in cols:
    print(attribute)
    print(spot00.groupby('target')[attribute].describe())
    print(30*'=')
# Out:
# danceability
#          count      mean       std     min      25%    50%    75%    max
# target
# 0       2936.0  0.455813  0.186816  0.0588  0.31375  0.459  0.594  0.968
# 1       2936.0  0.630049  0.148761  0.1130  0.52700  0.632  0.735  0.986
# ...
# loudness
#          count      mean       std     min       25%     50%      75%    max
# target
# 0       2936.0 -9.221220  6.454790 -47.327 -11.03925 -7.1950 -5.08175  1.137
# 1       2936.0 -5.677296  2.033377 -17.224  -6.77275 -5.4195 -4.24475 -0.884
# ...
# speechiness
#          count      mean       std     min     25%     50%       75%    max
# target
# 0       2936.0  0.086934  0.089242  0.0233  0.0389  0.0551  0.097625  0.950
# 1       2936.0  0.097785  0.100145  0.0224  0.0336  0.0499  0.119000  0.941
# ...
# acousticness
#          count      mean       std       min       25%      50%      75%  \
# target
# 0       2936.0  0.280740  0.366138  0.000000  0.000821  0.03845  0.59800
# ...

# %%
spot.groupby('target')['danceability'].describe()
# Out:
#          count      mean       std     min      25%    50%    75%    max
# target
# 0       2936.0  0.455813  0.186816  0.0588  0.31375  0.459  0.594  0.968
# 1       2936.0  0.630049  0.148761  0.1130  0.52700  0.632  0.735  0.986

# %%
spot.groupby('target').median()
# Out:
# C:\Users\Alkis\AppData\Local\Temp\ipykernel_2176\2648741696.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.median is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   spot.groupby('target').median()
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# target
# 0              0.459  0.7565  5.0   -7.1950   1.0       0.0551       0.03845
# 1              0.632  0.7360  5.0   -5.4195   1.0       0.0499       0.07120
#
#         instrumentalness  liveness  valence     tempo  duration_ms  \
# target
# 0                 0.0284     0.133    0.387  121.9325     245.3550
# 1                 0.0000     0.129    0.565  118.3800     235.0065
#
#         time_signature  chorus_hit  sections
# target
# 0                  4.0    37.38790      10.0
# 1                  4.0    34.94029      10.0

# %%
spot00[spot00['target']==1].groupby('artist').count().sort_values('track', ascending=False).head(20)
# Out:
#                    track  uri  danceability  energy  key  loudness  mode  \
# artist
# Toby Keith            27   27            27      27   27        27    27
# Tim McGraw            24   24            24      24   24        24    24
# Rascal Flatts         24   24            24      24   24        24    24
# Kenny Chesney         23   23            23      23   23        23    23
# George Strait         22   22            22      22   22        22    22
# Keith Urban           20   20            20      20   20        20    20
# Brad Paisley          20   20            20      20   20        20    20
# Britney Spears        19   19            19      19   19        19    19
# Alan Jackson          19   19            19      19   19        19    19
# Brooks & Dunn         17   17            17      17   17        17    17
# Taylor Swift          17   17            17      17   17        17    17
# P!nk                  15   15            15      15   15        15    15
# ...

# %%
spot00
# Out:
#                                                   track  \
# 0                                             Lucky Man
# 1                                        On The Hotline
# 2                                    Clouds Of Dementia
# 3                              Heavy Metal, Raise Hell!
# 4                                       I Got A Feelin'
# ...                                                 ...
# 5867                                        Summer Rain
# 5868                                              And I
# 5869  Mass in B minor BWV 232, Missa: Duetto - Chris...
# 5870                                               Loog
# 5871                               What The World Needs
#
#                      artist                                   uri  \
# 0         Montgomery Gentry  spotify:track:4GiXBCUF7H6YfNQsnBRIzl
# 1              Pretty Ricky  spotify:track:1zyqZONW985Cs4osz9wlsu
# 2                Candlemass  spotify:track:6cHZf7RbxXCKwEkgAZT4mY
# ...

# %% [markdown]
# # 00s diagrammata

# %%
for attribute in cols:
    plt.figure(figsize=(4,3))
    sns.barplot(x='target', y=attribute, data=spot, width=0.4).set_title(attribute)
    plt.xticks(rotation=0)
    plt.show()

# %%
spot2 = spot.copy()

# %%
spot2 = spot2[spot2['target']==1]

# %%
for attribute in cols:
    print(attribute)
    print(spot2.groupby('target')[attribute].describe())
    print(30*'=')
# Out:
# danceability
#          count      mean       std    min    25%    50%    75%    max
# target
# 1       2936.0  0.630049  0.148761  0.113  0.527  0.632  0.735  0.986
# ...
# loudness
#          count      mean       std     min      25%     50%      75%    max
# target
# 1       2936.0 -5.677296  2.033377 -17.224 -6.77275 -5.4195 -4.24475 -0.884
# ...
# speechiness
#          count      mean       std     min     25%     50%    75%    max
# target
# 1       2936.0  0.097785  0.100145  0.0224  0.0336  0.0499  0.119  0.941
# ...
# acousticness
#          count      mean       std       min     25%     50%      75%    max
# target
# 1       2936.0  0.148008  0.181653  0.000002  0.0149  0.0712  0.22425  0.994
# ...
# instrumentalness
#          count      mean       std  min  25%  50%       75%    max
# target
# 1       2936.0  0.008858  0.067285  0.0  0.0  0.0  0.000024  0.982
# ...
# valence
#          count      mean       std     min      25%    50%    75%    max
# target
# ...

# %%
to_delete=['uri','energy','key','mode','liveness','time_signature','chorus_hit','sections']

# %%
spot2 = spot2.drop(to_delete, axis=1)

# %%
spot2
# Out:
#                      track             artist  danceability  loudness  \
# 0                Lucky Man  Montgomery Gentry         0.578    -7.270
# 1           On The Hotline       Pretty Ricky         0.704    -5.477
# 4          I Got A Feelin'   Billy Currington         0.630    -4.353
# 7        Where I Come From       Alan Jackson         0.726    -8.136
# 8       Nothin' To Die For         Tim McGraw         0.481    -5.654
# ...                    ...                ...           ...       ...
# 5864            The Anthem     Good Charlotte         0.494    -3.127
# 5865                 I Can                Nas         0.837    -3.914
# 5867           Summer Rain        Carl Thomas         0.667   -10.488
# 5868                 And I              Ciara         0.691   -10.125
# 5871  What The World Needs            Wynonna         0.539    -5.566
#
#       speechiness  acousticness  instrumentalness  valence    tempo  \
# ...

# %%
spot2.describe()
# Out:
#        danceability     loudness  speechiness  acousticness  instrumentalness  \
# count   2936.000000  2936.000000  2936.000000   2936.000000       2936.000000
# mean       0.630049    -5.677296     0.097785      0.148008          0.008858
# std        0.148761     2.033377     0.100145      0.181653          0.067285
# min        0.113000   -17.224000     0.022400      0.000002          0.000000
# 25%        0.527000    -6.772750     0.033600      0.014900          0.000000
# 50%        0.632000    -5.419500     0.049900      0.071200          0.000000
# 75%        0.735000    -4.244750     0.119000      0.224250          0.000024
# max        0.986000    -0.884000     0.941000      0.994000          0.982000
#
#            valence        tempo    duration_ms  target
# count  2936.000000  2936.000000    2936.000000  2936.0
# mean      0.553791   120.283592  238862.943801     1.0
# std       0.223758    29.451686   43409.288675     0.0
# ...

# %%
spot2[spot2['danceability']>=0.735].sort_values('danceability')

# %%
spot2[spot2['loudness']<=-4.24475].sort_values('loudness')

# %%
spot2[spot2['speechiness']>=0.119000].sort_values('speechiness')

# %%
spot2[spot2['acousticness']>=0.224250].sort_values('acousticness')

# %%
spot2[spot2['valence']>=0.565000].sort_values('valence')

# %%
spot2[spot2['tempo']>=118.38].sort_values('tempo')

# %%
spot2[spot2['duration_ms']>=235006].sort_values('duration_ms')

# %%
# spot['duration_ms']=spot['duration_ms']/1000/60

# %% [markdown]
# # TELIKO ola mazi enomena

# %%
spot44['decade']=2000
alkis

# %%
alkis=spot44

# %%
alkis['duration_ms']=alkis['duration_ms']*1000

# %%
thanasis = pd.read_csv(r"dataset-of-10s.csv")

# %%
thanasis['decade']=2010

# %%
thanasis
# Out:
#                                     track                          artist  \
# 0                             Wild Things                    Alessia Cara
# 1                               Surfboard                       Esquivel!
# 2                            Love Someone                    Lukas Graham
# 3     Music To My Ears (feat. Tory Lanez)                   Keys N Krates
# 4           Juju On That Beat (TZ Anthem)  Zay Hilfigerrr & Zayion McCall
# ...                                   ...                             ...
# 6393                        Lotus Flowers                           Yolta
# 6394                    Calling My Spirit                     Kodak Black
# 6395                        Teenage Dream                      Katy Perry
# 6396                       Stormy Weather                  Oscar Peterson
# 6397                                 Dust                     Hans Zimmer
#
#                                        uri  danceability  energy  key  \
# ...

# %%
teliko = pd.DataFrame()

# %%
teliko = alkis.append(thanasis)
# Out:
# C:\Users\Alkis\AppData\Local\Temp\ipykernel_2176\878708116.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   teliko = alkis.append(thanasis)

# %%
teliko.groupby(['decade','target']).mean()
# Out:
# C:\Users\Alkis\AppData\Local\Temp\ipykernel_2176\1408681994.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   teliko.groupby(['decade','target']).mean()
#                danceability    energy       key  loudness      mode  \
# decade target
# 2000   0           0.455813  0.674414  5.292234 -9.221220  0.599114
#        1           0.630049  0.714608  5.260559 -5.677296  0.691076
# 2010   0           0.494692  0.653146  5.263520 -9.303840  0.630197
#        1           0.641633  0.682367  5.303532 -5.875753  0.660832
#
#                speechiness  acousticness  instrumentalness  liveness  \
# decade target
# 2000   0          0.086934      0.280740          0.292976  0.208374
#        1          0.097785      0.148008          0.008858  0.183907
# ...

# %%
teliko.groupby(['decade','target']).agg('mean')
# Out:
# C:\Users\Alkis\AppData\Local\Temp\ipykernel_2176\2986784859.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   teliko.groupby(['decade','target']).agg('mean')
#                danceability    energy       key  loudness      mode  \
# decade target
# 2000   0           0.455813  0.674414  5.292234 -9.221220  0.599114
#        1           0.630049  0.714608  5.260559 -5.677296  0.691076
# 2010   0           0.494692  0.653146  5.263520 -9.303840  0.630197
#        1           0.641633  0.682367  5.303532 -5.875753  0.660832
#
#                speechiness  acousticness  instrumentalness  liveness  \
# decade target
# 2000   0          0.086934      0.280740          0.292976  0.208374
#        1          0.097785      0.148008          0.008858  0.183907
# ...

# %%
teliko.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12270 entries, 0 to 6397
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track             12270 non-null  object
#  1   artist            12270 non-null  object
#  2   uri               12270 non-null  object
#  3   danceability      12270 non-null  float64
#  4   energy            12270 non-null  float64
#  5   key               12270 non-null  int64
#  6   loudness          12270 non-null  float64
#  7   mode              12270 non-null  int64
#  8   speechiness       12270 non-null  float64
#  9   acousticness      12270 non-null  float64
#  10  instrumentalness  12270 non-null  float64
#  11  liveness          12270 non-null  float64
#  12  valence           12270 non-null  float64
#  13  tempo             12270 non-null  float64
#  14  duration_ms       12270 non-null  float64
#  15  time_signature    12270 non-null  int64
# ...

# %%
teliko.drop(['uri', 'energy', 'key', 'mode', 'mode', 'instrumentalness', 'liveness', 'time_signature', 'chorus_hit', 'sections'], axis=1, inplace=True)

# %%
teliko
# Out:
#                          track             artist  danceability  loudness  \
# 0                    Lucky Man  Montgomery Gentry         0.578    -7.270
# 1               On The Hotline       Pretty Ricky         0.704    -5.477
# 2           Clouds Of Dementia         Candlemass         0.162    -3.009
# 3     Heavy Metal, Raise Hell!      Zwartketterij         0.188    -3.745
# 4              I Got A Feelin'   Billy Currington         0.630    -4.353
# ...                        ...                ...           ...       ...
# 6393             Lotus Flowers              Yolta         0.172   -14.430
# 6394         Calling My Spirit        Kodak Black         0.910    -9.954
# 6395             Teenage Dream         Katy Perry         0.719    -4.581
# 6396            Stormy Weather     Oscar Peterson         0.600   -16.070
# 6397                      Dust        Hans Zimmer         0.121   -23.025
#
#       speechiness  acousticness  valence    tempo  duration_ms  target  decade
# ...

# %%
teliko.groupby('decade').mean()
# Out:
# C:\Users\Alkis\AppData\Local\Temp\ipykernel_2176\3331743227.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   teliko.groupby('decade').mean()
#         danceability  loudness  speechiness  acousticness   valence  \
# decade
# 2000        0.542931 -7.449258     0.092360      0.214374  0.482262
# 2010        0.568163 -7.589796     0.098018      0.216928  0.443734
#
#              tempo    duration_ms  target
# decade
# 2000    121.613018  258170.628236     0.5
# 2010    122.353871  236704.210378     0.5

# %%
teliko.groupby(['decade','target']).median()['danceability'].plot.bar(figsize=(5,4))

# %% [markdown]
# # TELIKO:enomena DIAGRAMMATA

# %%
cols_teliko=['danceability' , 'loudness', 'speechiness', 'acousticness', 'valence', 'tempo', 'duration_ms']

# %%
for attribute in cols_teliko:
    plt.figure(figsize=(4,3))
    sns.barplot(x1='target', y=attribute, data=teliko, width=0.4).set_title(attribute)
    plt.xticks(rotation=0)
    plt.show()

# %%
teliko[teliko['target']==1].groupby('decade').describe()
# Out:
#        danceability                                                         \
#               count      mean       std    min    25%    50%    75%    max
# decade
# 2000         2936.0  0.630049  0.148761  0.113  0.527  0.632  0.735  0.986
# 2010         3199.0  0.641633  0.142438  0.201  0.547  0.645  0.741  0.981
#
#        loudness                                                               \
#           count      mean       std     min      25%     50%      75%    max
# decade
# 2000     2936.0 -5.677296  2.033377 -17.224 -6.77275 -5.4195 -4.24475 -0.884
# 2010     3199.0 -5.875753  2.203026 -23.023 -6.97200 -5.5670 -4.38900 -0.716
#
#        speechiness                                                             \
#              count      mean       std     min     25%     50%     75%    max
# decade
# 2000        2936.0  0.097785  0.100145  0.0224  0.0336  0.0499  0.1190  0.941
# 2010        3199.0  0.107524  0.106353  0.0225  0.0383  0.0586  0.1325  0.733
#
# ...

# %%
teliko[teliko['target']==1].groupby('decade').count()
# Out:
#         track  artist  danceability  loudness  speechiness  acousticness  \
# decade
# 2000     2936    2936          2936      2936         2936          2936
# 2010     3199    3199          3199      3199         3199          3199
#
#         valence  tempo  duration_ms  target
# decade
# 2000       2936   2936         2936    2936
# 2010       3199   3199         3199    3199

# %%
teliko
# Out:
#                          track             artist  danceability  loudness  \
# 0                    Lucky Man  Montgomery Gentry         0.578    -7.270
# 1               On The Hotline       Pretty Ricky         0.704    -5.477
# 2           Clouds Of Dementia         Candlemass         0.162    -3.009
# 3     Heavy Metal, Raise Hell!      Zwartketterij         0.188    -3.745
# 4              I Got A Feelin'   Billy Currington         0.630    -4.353
# ...                        ...                ...           ...       ...
# 6393             Lotus Flowers              Yolta         0.172   -14.430
# 6394         Calling My Spirit        Kodak Black         0.910    -9.954
# 6395             Teenage Dream         Katy Perry         0.719    -4.581
# 6396            Stormy Weather     Oscar Peterson         0.600   -16.070
# 6397                      Dust        Hans Zimmer         0.121   -23.025
#
#       speechiness  acousticness  valence    tempo  duration_ms  target  decade
# ...

# %% [markdown]
# # THANASIS

# %% [markdown]
# # DIGRAMMATA THANASIS

# %%
for attribute in cols_teliko:
    plt.figure(figsize=(4,3))
    sns.barplot(x='target', y=attribute, data=thanasis, width=0.4).set_title(attribute)
    plt.xticks(rotation=0)
    plt.show()

# %%
tns1 = thanasis[thanasis['target']==1].sort_values('danceability',ascending=False)

# %%
tns1[cols_teliko].describe()
# Out:
#        danceability     loudness  speechiness  acousticness      valence  \
# count   3199.000000  3199.000000  3199.000000   3199.000000  3199.000000
# mean       0.641633    -5.875753     0.107524      0.162173     0.493813
# std        0.142438     2.203026     0.106353      0.206048     0.216325
# min        0.201000   -23.023000     0.022500      0.000025     0.035200
# 25%        0.547000    -6.972000     0.038300      0.020550     0.325000
# 50%        0.645000    -5.567000     0.058600      0.073600     0.487000
# 75%        0.741000    -4.389000     0.132500      0.221000     0.654500
# max        0.981000    -0.716000     0.733000      0.992000     0.976000
#
#              tempo    duration_ms
# count  3199.000000    3199.000000
# mean    123.524576  220502.664270
# std      29.052186   43628.031893
# min      48.718000   59387.000000
# 25%      99.967000  195125.000000
# 50%     123.815000  216573.000000
# 75%     142.673000  239673.000000
# ...

# %%
teliko[teliko['speechiness']>=0.733].sort_values('speechiness')
# Out:
#                                           track              artist  \
# 424                               Growing Pains        Alessia Cara
# 2458                                Vuoi sapere        Metal Carter
# 1123                  Sri Venkatesa Suprabhatam  M. S. Subbulakshmi
# 5283                               Touch, Pt. 1    Morton Subotnick
# 3621                        Let's Rock Shall We   Throwing Toasters
# 4137                       Dad's a Psych - Live             Matty B
# 3431  Subliminal Heavy Metal - Original Version      Carnifull Trio
# 3311                                 Easy Ridin              ohbliv
# 3026                                 Butting In        Illingsworth
# 954               Bendix 1: The Tomorrow People       Raymond Scott
# 3158                          Should've Said No        Taylor Swift
# 4293                           Build Me A House       Greg Behrendt
# 1038                              Friendly Folk    Bernard Cribbins
# ...

# %%
spot2[spot2['loudness']<=-4.24475].sort_values('loudness')

spot2[spot2['speechiness']>=0.119000].sort_values('speechiness')

spot2[spot2['acousticness']>=0.224250].sort_values('acousticness')

spot2[spot2['valence']>=0.565000].sort_values('valence')

spot2[spot2['tempo']>=118.38].sort_values('tempo')

spot2[spot2['duration_ms']>=235006].sort_values('duration_ms')
